# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (30,8)

# %%
df2 = pd.read_parquet('./datasets/raw/input_dataset-2.parquet').reset_index()
df1

# %%
df['timepoints']
# Out:
# 0         1970-12-19 09:51:44
# 1         1970-12-19 09:51:45
# 2         1970-12-19 09:51:46
# 3         1970-12-19 09:51:47
# 4         1970-12-19 09:51:48
#                   ...
# 1874082   1971-01-25 11:06:44
# 1874083   1971-01-25 11:06:45
# 1874084   1971-01-25 11:06:46
# 1874085   1971-01-25 11:06:47
# 1874086   1971-01-25 11:06:48
# Name: timepoints, Length: 1874087, dtype: datetime64[ns]

# %%
plt.plot(df['timepoints'], df['Bolt_1_Tensile'])
